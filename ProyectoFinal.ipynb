# %% [markdown]
# <a href="https://colab.research.google.com/github/esparraguito/TemasEspeciales/blob/main/ProyectoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Introducción.
# Analisis de datos:
# El análisis de datos es el estudio exhaustivo de un conjunto de información cuyo objetivo es obtener conclusiones que permitan a una empresa o entidad tomar una decisión.
#
# Es decir, nos referimos a la examinación e interpretación de una base de datos. Esto, con el fin de llegar a la resolución de un problema o cuestionamiento.
#
# Durante este análisis, los datos pueden ser objeto de operaciones, por ejemplo, para obtener indicadores estadísticos.
#
#
#
#
# ¿Por qué hare el analisis al siguiente DataSet?
# Spotify es una gran empresa si de distribucion de musica hablamos, es por ende una de las mejores plataformas para analisar el tipo de musica mas escuchada en la ultima decada (2009-2019), como objetivo tengo analisar que herramientas son las que mas usan las canciones mas populares como puede ser: acustica, pop, mas energizada.

# %%
import numpy as np                 # numpy
import pandas as pd                # pandas 
import matplotlib.pyplot as plt    # matplotlib
import seaborn as sns          
import plotly.express as px    
import matplotlib.pyplot as plt

# %% [markdown]
# //Carga de datos.

# %%
#Carga de Datos

musica = pd.read_csv('/content/Spotify 2010 - 2019 Top 100.csv')
musica
# Out:
#                                               title            artist  \
# 0                     STARSTRUKK (feat. Katy Perry)             3OH!3
# 1                       My First Kiss (feat. Ke$ha)             3OH!3
# 2                                   I Need A Dollar        Aloe Blacc
# 3     Airplanes (feat. Hayley Williams of Paramore)             B.o.B
# 4                 Nothin' on You (feat. Bruno Mars)             B.o.B
# ...                                             ...               ...
# 998                     Strike a Pose (feat. Aitch)  Young T & Bugsey
# 999       The London (feat. J. Cole & Travis Scott)        Young Thug
# 1000                                            NaN               NaN
# 1001                                            NaN               NaN
# 1002                                            NaN               NaN
#
#         top genre  year released       added    bpm  nrgy  dnce   dB  live  \
# ...

# %% [markdown]
# Visualizacion de datos.

# %%
musica.dtypes
# Out:
# title             object
# artist            object
# top genre         object
# year released    float64
# added             object
# bpm              float64
# nrgy             float64
# dnce             float64
# dB               float64
# live             float64
# val              float64
# dur              float64
# acous            float64
# spch             float64
# pop              float64
# top year          object
# artist type       object
# dtype: object

# %%
musica.head()
# Out:
#                                            title      artist    top genre  \
# 0                  STARSTRUKK (feat. Katy Perry)       3OH!3    dance pop
# 1                    My First Kiss (feat. Ke$ha)       3OH!3    dance pop
# 2                                I Need A Dollar  Aloe Blacc     pop soul
# 3  Airplanes (feat. Hayley Williams of Paramore)       B.o.B  atl hip hop
# 4              Nothin' on You (feat. Bruno Mars)       B.o.B  atl hip hop
#
#    year released       added    bpm  nrgy  dnce   dB  live   val    dur  \
# 0         2009.0  2022‑02‑17  140.0  81.0  61.0 -6.0  23.0  23.0  203.0
# 1         2010.0  2022‑02‑17  138.0  89.0  68.0 -4.0  36.0  83.0  192.0
# 2         2010.0  2022‑02‑17   95.0  48.0  84.0 -7.0   9.0  96.0  243.0
# 3         2010.0  2022‑02‑17   93.0  87.0  66.0 -4.0   4.0  38.0  180.0
# 4         2010.0  2022‑02‑17  104.0  85.0  69.0 -6.0   9.0  74.0  268.0
#
#    acous  spch   pop top year artist type
# 0    0.0   6.0  70.0   2010.0         Duo
# ...

# %%
musica.describe() #describe los tipos de variables de los datos
# Out:
#        year released          bpm         nrgy         dnce           dB  \
# count    1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     2014.390000   121.262000    69.502000    66.876000    -5.663000
# std         3.241359    26.238022    15.961415    13.121921     2.025224
# min      1975.000000    65.000000     6.000000    19.000000   -18.000000
# 25%      2012.000000   100.000000    59.000000    59.000000    -7.000000
# 50%      2014.000000   122.000000    71.000000    68.000000    -5.000000
# 75%      2017.000000   134.000000    81.250000    75.000000    -4.000000
# max      2021.000000   206.000000    98.000000    96.000000    -1.000000
#
#               live          val          dur       acous         spch  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean     17.911000    50.901000   220.406000    14.36900    10.064000
# std      13.431511    21.563399    39.927677    19.45403     9.276743
# ...

# %%
#ninguna columna tiene datos perdidos
print(f"Datos perdidos en cada variable: \n{musica.isnull().sum()}")
# Out:
# Datos perdidos en cada variable:
# title            0
# artist           0
# top genre        0
# year released    0
# added            0
# bpm              0
# nrgy             0
# dnce             0
# dB               0
# live             0
# val              0
# dur              0
# acous            0
# spch             0
# pop              0
# top year         0
# artist type      0
# dtype: int64

# %% [markdown]
#
#  Filtramos informacion quitando dos generos musicales

# %%
#Consultamos generos y el año de realización
generos = musica[['top genre','top year']].sort_values(by='top year',ascending=False)
# df20.drop_duplicates(keep='first', inplace=False)
generos[:20]
# Out:
#                 top genre top year
# 999           atl hip hop   2019.0
# 936           melodic rap   2019.0
# 926             dance pop   2019.0
# 927  alternative pop rock   2019.0
# 928      canadian hip hop   2019.0
# 929             dance pop   2019.0
# 930                   pop   2019.0
# 931                   pop   2019.0
# 932                   pop   2019.0
# 933           melodic rap   2019.0
# 934         dark clubbing   2019.0
# 935             dance pop   2019.0
# 937           melodic rap   2019.0
# 949               art pop   2019.0
# 938     conscious hip hop   2019.0
# 939             dance pop   2019.0
# 940             dance pop   2019.0
# 941              boy band   2019.0
# 942              boy band   2019.0
# 943           chicago rap   2019.0

# %%
#clasificamos por año y que generos usan nrgy  en una escala del 0 al 100 como sintentizador 
sns.relplot(x="top year",y="nrgy", hue="top genre", data=musica)
print()

# %%
#Que cuantas filas tiene datos nulos dentro de las siguientes columnas 
musica.isnull().sum()
# Out:
# title            3
# artist           3
# top genre        3
# year released    3
# added            3
# bpm              3
# nrgy             3
# dnce             3
# dB               3
# live             3
# val              3
# dur              3
# acous            3
# spch             3
# pop              3
# top year         3
# artist type      3
# dtype: int64

# %%
#Comprobando valores nulos 
valores_nulos = musica.isna() #Detectar valores NAN, arroja booleanos 
columna_vacia = valores_nulos.any() #ANY Devuelve False a menos que haya al menos un elemento dentro de una serie oa lo largo de un eje de Dataframe que sea True o equivalente (por ejemplo, distinto de cero o no vacío).
columna_vacia
# Out:
# title            True
# artist           True
# top genre        True
# year released    True
# added            True
# bpm              True
# nrgy             True
# dnce             True
# dB               True
# live             True
# val              True
# dur              True
# acous            True
# spch             True
# pop              True
# top year         True
# artist type      True
# dtype: bool

# %%
#consultamos que canciones se realizaron en 2010
musica[musica['year released']==2010]
# Out:
#                                              title             artist  \
# 1                      My First Kiss (feat. Ke$ha)              3OH!3
# 2                                  I Need A Dollar         Aloe Blacc
# 3    Airplanes (feat. Hayley Williams of Paramore)              B.o.B
# 4                Nothin' on You (feat. Bruno Mars)              B.o.B
# 5                       Magic (feat. Rivers Cuomo)              B.o.B
# ..                                             ...                ...
# 194                                 If I Die Young     The Band Perry
# 196                More - RedOne Jimmy Joker Remix              Usher
# 197            No Hands (feat. Roscoe Dash & Wale)  Waka Flocka Flame
# 225                           Hot Right Now - Edit           DJ Fresh
# 228                        Lights - Single Version     Ellie Goulding
#
#                 top genre  year released       added    bpm  nrgy  dnce   dB  \
# ...

# %%
musica = musica.iloc[0:999]

# %%
#3 valores inferiores son nulos en todas las columnas, eliminémoslos

musica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          999 non-null    object
#  1   artist         999 non-null    object
#  2   top genre      999 non-null    object
#  3   year released  999 non-null    float64
#  4   added          999 non-null    object
#  5   bpm            999 non-null    float64
#  6   nrgy           999 non-null    float64
#  7   dnce           999 non-null    float64
#  8   dB             999 non-null    float64
#  9   live           999 non-null    float64
#  10  val            999 non-null    float64
#  11  dur            999 non-null    float64
#  12  acous          999 non-null    float64
#  13  spch           999 non-null    float64
#  14  pop            999 non-null    float64
#  15  top year       999 non-null    object
#  16  artist type    999 non-null    object
# ...

# %%
#La mayoría del género superior es dance pop.
musica.groupby('top genre')['top genre'].count().sort_values(ascending=False)
# Out:
# top genre
# dance pop        361
# pop               57
# atl hip hop       38
# art pop           37
# hip hop           21
#                 ...
# idol               1
# indie folk         1
# dark clubbing      1
# basshall           1
# acoustic pop       1
# Name: top genre, Length: 132, dtype: int64

# %%
#Qué canciones tienen más acustica

musica['acous'].sort_values(ascending=False)
# Out:
# 916    98.0
# 675    97.0
# 291    95.0
# 107    95.0
# 110    94.0
#        ...
# 871     0.0
# 385     0.0
# 382     0.0
# 381     0.0
# 0       0.0
# Name: acous, Length: 999, dtype: float64

# %%
#Canciones que tienen mas pop
musica['pop'].sort_values(ascending=False)
# Out:
# 392    95.0
# 394    94.0
# 914    91.0
# 211    91.0
# 231    91.0
#        ...
# 225    41.0
# 129    40.0
# 60     39.0
# 205    39.0
# 182    35.0
# Name: pop, Length: 999, dtype: float64

# %%
#Canciones mas energizadas
musica['nrgy'].sort_values(ascending=False)
# Out:
# 70     98.0
# 312    98.0
# 254    97.0
# 422    97.0
# 88     97.0
#        ...
# 613    17.0
# 291    16.0
# 448    15.0
# 916    11.0
# 675     6.0
# Name: nrgy, Length: 999, dtype: float64

# %%
#Generos mas escuchados 
musica['top genre']
# Out:
# 0        dance pop
# 1        dance pop
# 2         pop soul
# 3      atl hip hop
# 4      atl hip hop
#           ...
# 994            pop
# 995        hip hop
# 996        hip hop
# 997          grime
# 998      afroswing
# Name: top genre, Length: 999, dtype: object

# %%
#Tabla de año de realizacion de la cancion con respecto a el año que estuvo en el top 
px.scatter(musica, x='year released',y='top year', color=musica['artist'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
musica.acous.hist()
plt.show()

# %%
pd.plotting.scatter_matrix(musica);
plt.show()

# %%
#En la decada del 2010-2020 se realizo mas musica pop
musica.plot.scatter(x="year released", y="pop")
plt.show()

# %%
#en 2016 se realizo hubo mas canciones en el Top year 
musica.plot.scatter(x="year released", y="top year")
plt.show()

# %% [markdown]
# // Cluster

# %%
musica.loc[:, ['title']]
# Out:
#                                              title
# 0                    STARSTRUKK (feat. Katy Perry)
# 1                      My First Kiss (feat. Ke$ha)
# 2                                  I Need A Dollar
# 3    Airplanes (feat. Hayley Williams of Paramore)
# 4                Nothin' on You (feat. Bruno Mars)
# ..                                             ...
# 994                          You Need To Calm Down
# 995                                     SICKO MODE
# 996                                      EARFQUAKE
# 997                      Boasty (feat. Idris Elba)
# 998                    Strike a Pose (feat. Aitch)
#
# [999 rows x 1 columns]

# %%
f, axs = plt.subplots(1, 2, figsize=(20, 20), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=musica, x="dur", y="top genre", hue="artist type", ax=axs[0], legend = True)
sns.displot(data=musica, x="dur", hue="artist type", multiple="stack", kind="kde")
sns.histplot(data=musica, x="artist type", hue="artist type", shrink=.8, alpha=.8, legend=False, ax=axs[1])

# %%
musica.count()
# Out:
# title            999
# artist           999
# top genre        999
# year released    999
# added            999
# bpm              999
# nrgy             999
# dnce             999
# dB               999
# live             999
# val              999
# dur              999
# acous            999
# spch             999
# pop              999
# top year         999
# artist type      999
# dtype: int64

# %% [markdown]
# Concluciones
# De lo anterior visto llegamos  podemos observar que el genero pop y el sintetizador que energiza las canciones son herramientas que se utilizan mucho entre los primeros lugares de musica en el top of the year, asimismo, la popularizacion de las canciones comenzaron a aumentar a partir del año 2016, canciones hechas en 1980-2000 tienen muy baja popularidad entre la decada del 2010 y 2019, tambien, entre lkass canciones mas populares se encuentran realizadas por un solo, en cambio las populares en menor cantidad se realizaron bajo el formato de trio.
